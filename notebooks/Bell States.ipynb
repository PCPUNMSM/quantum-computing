# %% [markdown]
# # Bell States

# %% [markdown]
# ## Hands on code!

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere

# %% [markdown]
# ### The case |00>

# %% [markdown]
# $$
# \left|00\right\rangle
#     \xrightarrow{H} \frac{1}{\sqrt{2}}\left(\left|00\right\rangle + \left|10\right\rangle\right)
#      \xrightarrow{CX} \frac{1}{\sqrt{2}}\left(\left|00\right\rangle + \left|11\right\rangle\right)
# $$

# %%
sv = Statevector.from_label("00")
plot_state_qsphere(sv.data)

# %%
mycircuit = QuantumCircuit(2)
mycircuit.h(0)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %%
mycircuit.cx(0, 1)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %% [markdown]
# ### The case |01>

# %% [markdown]
# $$
# \left|01\right\rangle
#     \xrightarrow{H} \frac{1}{\sqrt{2}}\left(\left|01\right\rangle + \left|11\right\rangle\right)
#      \xrightarrow{CX} \frac{1}{\sqrt{2}}\left(\left|01\right\rangle + \left|10\right\rangle\right)
# $$

# %%
sv = Statevector.from_label("01")
plot_state_qsphere(sv.data)

# %%
mycircuit = QuantumCircuit(2)
mycircuit.h(1)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %%
mycircuit.cx(1, 0)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %% [markdown]
# ### The case |10>

# %% [markdown]
# $$
# \left|10\right\rangle
#     \xrightarrow{H} \frac{1}{\sqrt{2}}\left(\left|00\right\rangle - \left|10\right\rangle\right)
#      \xrightarrow{CX} \frac{1}{\sqrt{2}}\left(\left|00\right\rangle - \left|11\right\rangle\right)
# $$

# %%
sv = Statevector.from_label("10")
plot_state_qsphere(sv.data)

# %%
mycircuit = QuantumCircuit(2)
mycircuit.h(1)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %%
mycircuit.cx(1, 0)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %% [markdown]
# ### The case |11>

# %% [markdown]
# $$
# \left|11\right\rangle
#     \xrightarrow{H} \frac{1}{\sqrt{2}}\left(\left|01\right\rangle - \left|11\right\rangle\right)
#      \xrightarrow{CX} \frac{1}{\sqrt{2}}\left(\left|01\right\rangle - \left|10\right\rangle\right)
# $$

# %%
sv = Statevector.from_label("11")
plot_state_qsphere(sv.data)

# %%
mycircuit = QuantumCircuit(2)
mycircuit.h(1)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)

# %%
mycircuit.cx(1, 0)
mycircuit.draw("mpl")

# %%
new_sv = sv.evolve(mycircuit)
plot_state_qsphere(new_sv.data)
